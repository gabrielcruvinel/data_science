# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains

from urllib.request import urlopen, urlretrieve
import time
from bs4 import BeautifulSoup
import requests

# %%
driver=webdriver.Chrome('./webdrivers/chromedriver.exe')
driver.implicitly_wait(10) 
driver.get("http://books.toscrape.com/catalogue/page-1.html")
print(driver.page_source)
# Out:
# <html lang="en-us" class="no-js"><!--<![endif]--><head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <meta name="created" content="24th Jun 2016 09:30">
#         <meta name="description" content="">
#         <meta name="viewport" content="width=device-width">
#         <meta name="robots" content="NOARCHIVE,NOCACHE">
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#
#
#             <link rel="shortcut icon" href="../static/oscar/favicon.ico">
#
#
#
#
#
#
#         <link rel="stylesheet" type="text/css" href="../static/oscar/css/styles.css">
#
#     <link rel="stylesheet" href="../static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css">
# ...

# %%
qtd_pags = driver.find_element_by_xpath("/html/body/div/div/div/div/section/div[2]/div/ul/li[1]").text
qtd_pags = int(qtd_pags.split()[-1])
qtd_pags
# Out:
# 50

# %%
'''
O nome do livro.
A categoria do livro.
O número de estrelas que o livro recebeu.
O preço do livro.
Se o livro está em Estoque ou não.

'''
# Out:
# '\nO nome do livro.\nA categoria do livro.\nO número de estrelas que o livro recebeu.\nO preço do livro.\nSe o livro está em Estoque ou não.\n\n'

# %%
list_categ_pag = driver.find_elements_by_xpath("//ul[@class = 'nav nav-list']//li[not(@class)]")

print(list_categ_pag)
books = []
book = {}

'''
for category in list_categ_pag:
    

    for link_book in list_books_pag:
    
    driver.implicitly_wait(10) 
    link_book.click()
    response = urlopen(driver.current_url)
    html = response.read().decode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')
    
    
    book['Name'] = soup.find('li', {"class":"active"}).getText()
    #book_name = soup.find('li', {"class":"active"}).getText()
    
    #intero pela lista procurando somente os links, apos isso pego somente o texto do ultimo elemento
    book['Category'] = soup.find('ul', {"class": "breadcrumb"}).findAll('a')[-1].getText()
    #book_categ = soup.find('ul', {"class": "breadcrumb"}).findAll('a')[-1].getText()
    
    book['Price'] = soup.find('p', {"class":"price_color"}).getText()
    #book_price = soup.find('p', {"class":"price_color"}).getText()
    
    book['In_Stock'] = soup.find('table', {"class":"table table-striped"}).findAll('td')[-2].getText()
    #book_stock = soup.find('table', {"class":"table table-striped"}).findAll('td')[-2].getText()
    
    book['Classification'] = driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/article/div[1]/div[2]/p[3]").get_attribute("class").split()[-1]
    #classification = driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/article/div[1]/div[2]/p[3]").get_attribute("class").split()[-1]
    
    
    driver.back()
    print(book)
    
'''
#interando por pagina
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bcb26e39eb2937c24071f31d0ba1d25d", element="944f494c-b740-4ed2-91e5-79eb768e553f")>, <selenium.webdriver.remote.webelement.WebElement (session="bcb26e39eb2937c24071f31d0ba1d25d", element="250baef1-68e2-496d-9a28-c55c89c90e2a")>, <selenium.webdriver.remote.webelement.WebElement (session="bcb26e39eb2937c24071f31d0ba1d25d", element="6133b3f9-f0b6-4a0a-9b1e-4fc1e1b81c72")>, <selenium.webdriver.remote.webelement.WebElement (session="bcb26e39eb2937c24071f31d0ba1d25d", element="bca82138-681b-42f3-a9c0-4b2cfdb0759e")>, <selenium.webdriver.remote.webelement.WebElement (session="bcb26e39eb2937c24071f31d0ba1d25d", element="859f4f22-b55c-405b-92ce-0fd6ab7424d8")>, <selenium.webdriver.remote.webelement.WebElement (session="bcb26e39eb2937c24071f31d0ba1d25d", element="2ebcfec5-09cf-46f9-b102-9836cf1c4017")>, <selenium.webdriver.remote.webelement.WebElement (session="bcb26e39eb2937c24071f31d0ba1d25d", element="7f88273f-0282-48b6-857f-41e5b4
# ...

# %%
len(list_books_pag)
# Out:
# 20

# %%
vetor_teste = ["p", "F"]
print("".join(vetor_teste))
# Out:
# pF

# %%
for letra in vetor_teste:
    print(letra)
# Out:
# p
# F

# %%
vetor_teste_palavra = ["pf", "policia"]

for palavra in vetor_teste_palavra:
    print(palavra)
# Out:
# pf
# policia

# %%
for palavra in vetor_teste_palavra:
    for letra in palavra:
        print(letra)
    print("********")
# Out:
# p
# f
# ********
# p
# o
# l
# i
# c
# i
# a
# ********

# %%
frase = "aqui nois constroi fibra"

for letra in frase:
    print(letra)
# Out:
# a
# q
# u
# i
#
# n
# o
# i
# s
#
# c
# o
# n
# s
# t
# r
# o
# i
#
# f
# i
# b
# r
# a
